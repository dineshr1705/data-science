# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fifa = pd.read_csv('fifa.csv')

# %%
fifa
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
sns.lineplot(data = fifa)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (16,7))
sns.lineplot(data = fifa)
# Out:
# <AxesSubplot:>

# %%
spotify = pd.read_csv('spotify.csv')

# %%
spotify.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
spotify.Date.tolist()
# Out:
# ['2017-01-06',
#  '2017-01-07',
#  '2017-01-08',
#  '2017-01-09',
#  '2017-01-10',
#  '2017-01-11',
#  '2017-01-12',
#  '2017-01-13',
#  '2017-01-14',
#  '2017-01-15',
#  '2017-01-16',
#  '2017-01-17',
#  '2017-01-18',
#  '2017-01-19',
#  '2017-01-20',
#  '2017-01-21',
#  '2017-01-22',
#  '2017-01-23',
#  '2017-01-24',
#  '2017-01-25',
#  '2017-01-26',
#  '2017-01-27',
#  '2017-01-28',
#  '2017-01-29',
#  '2017-01-30',
#  '2017-01-31',
#  '2017-02-01',
#  '2017-02-02',
#  '2017-02-03',
#  '2017-02-04',
#  '2017-02-05',
#  '2017-02-06',
#  '2017-02-07',
#  '2017-02-08',
#  '2017-02-09',
#  '2017-02-10',
#  '2017-02-11',
#  '2017-02-12',
#  '2017-02-13',
#  '2017-02-14',
#  '2017-02-15',
#  '2017-02-16',
#  '2017-02-17',
#  '2017-02-18',
#  '2017-02-19',
#  '2017-02-20',
#  '2017-02-21',
#  '2017-02-22',
#  '2017-02-23',
#  '2017-02-24',
#  '2017-02-25',
#  '2017-02-26',
#  '2017-02-27',
#  '2017-02-28',
#  '2017-03-01',
#  '2017-03-02',
#  '2017-03-03',
#  '2017-03-04',
#  '2017-03-05',
#  '2017-03-06',
#  '2017-03-07',
#  '2017-03-08',
#  '2017-03-09',
#  '2017-03-10',
#  '2017-03-11',
#  '2017-03-12',
#  '2017-03-13',
#  '2017-03-14',
#  '2017-03-15',
#  '2017-03-16',
#  '2017-03-17',
#  '2017-03-18',
#  '2017-03-19',
#  '2017-03-20',
#  '2017-03-21',
#  '2017-03-22',
#  '2017-03-23',
#  '2017-03-24',
#  '2017-03-25',
#  '2017-03-26',
#  '2017-03-27',
#  '2017-03-28',
#  '2017-03-29',
#  '2017-03-30',
#  '2017-03-31',
#  '2017-04-01',
#  '2017-04-02',
#  '2017-04-03',
#  '2017-04-04',
#  '2017-04-05',
#  '2017-04-06',
#  '2017-04-07',
#  '2017-04-08',
#  '2017-04-09',
#  '2017-04-10',
#  '2017-04-11',
#  '2017-04-12',
#  '2017-04-13',
#  '2017-04-14',
#  '2017-04-15',
#  '2017-04-16',
#  '2017-04-17',
#  '2017-04-18',
#  '2017-04-19',
#  '2017-04-20',
#  '2017-04-21',
#  '2017-04-22',
#  '2017-04-23',
#  '2017-04-24',
#  '2017-04-25',
#  '2017-04-26',
#  '2017-04-27',
#  '2017-04-28',
#  '2017-04-29',
#  '2017-04-30',
#  '2017-05-01',
#  '2017-05-02',
#  '2017-05-03',
#  '2017-05-04',
#  '2017-05-05',
#  '2017-05-06',
#  '2017-05-07',
#  '2017-05-08',
#  '2017-05-09',
#  '2017-05-10',
#  '2017-05-11',
#  '2017-05-12',
#  '2017-05-13',
#  '2017-05-14',
#  '2017-05-15',
#  '2017-05-16',
#  '2017-05-17',
#  '2017-05-18',
#  '2017-05-19',
#  '2017-05-20',
#  '2017-05-21',
#  '2017-05-22',
#  '2017-05-23',
#  '2017-05-24',
#  '2017-05-25',
#  '2017-05-26',
#  '2017-05-27',
#  '2017-05-28',
#  '2017-05-29',
#  '2017-06-01',
#  '2017-06-03',
#  '2017-06-04',
#  '2017-06-05',
#  '2017-06-06',
#  '2017-06-07',
#  '2017-06-08',
#  '2017-06-09',
#  '2017-06-10',
#  '2017-06-11',
#  '2017-06-12',
#  '2017-06-13',
#  '2017-06-14',
#  '2017-06-15',
#  '2017-06-16',
#  '2017-06-17',
#  '2017-06-18',
#  '2017-06-19',
#  '2017-06-20',
#  '2017-06-21',
#  '2017-06-22',
#  '2017-06-23',
#  '2017-06-24',
#  '2017-06-25',
#  '2017-06-26',
#  '2017-06-27',
#  '2017-06-28',
#  '2017-06-29',
#  '2017-06-30',
#  '2017-07-01',
#  '2017-07-02',
#  '2017-07-03',
#  '2017-07-04',
#  '2017-07-05',
#  '2017-07-06',
#  '2017-07-07',
#  '2017-07-08',
#  '2017-07-09',
#  '2017-07-10',
#  '2017-07-11',
#  '2017-07-12',
#  '2017-07-13',
#  '2017-07-14',
#  '2017-07-15',
#  '2017-07-16',
#  '2017-07-17',
#  '2017-07-18',
#  '2017-07-19',
#  '2017-07-20',
#  '2017-07-21',
#  '2017-07-22',
#  '2017-07-23',
#  '2017-07-24',
#  '2017-07-25',
#  '2017-07-26',
#  '2017-07-27',
#  '2017-07-28',
#  '2017-07-29',
#  '2017-07-30',
#  '2017-07-31',
#  '2017-08-01',
#  '2017-08-02',
#  '2017-08-03',
#  '2017-08-04',
#  '2017-08-05',
#  '2017-08-06',
#  '2017-08-07',
#  '2017-08-08',
#  '2017-08-09',
#  '2017-08-10',
#  '2017-08-11',
#  '2017-08-12',
#  '2017-08-13',
#  '2017-08-14',
#  '2017-08-15',
#  '2017-08-16',
#  '2017-08-17',
#  '2017-08-18',
#  '2017-08-19',
#  '2017-08-20',
#  '2017-08-21',
#  '2017-08-22',
#  '2017-08-23',
#  '2017-08-24',
#  '2017-08-25',
#  '2017-08-26',
#  '2017-08-27',
#  '2017-08-28',
#  '2017-08-29',
#  '2017-08-30',
#  '2017-08-31',
#  '2017-09-01',
#  '2017-09-02',
#  '2017-09-03',
#  '2017-09-04',
#  '2017-09-05',
#  '2017-09-06',
#  '2017-09-07',
#  '2017-09-08',
#  '2017-09-09',
#  '2017-09-10',
#  '2017-09-11',
#  '2017-09-12',
#  '2017-09-13',
#  '2017-09-14',
#  '2017-09-15',
#  '2017-09-16',
#  '2017-09-17',
#  '2017-09-18',
#  '2017-09-19',
#  '2017-09-20',
#  '2017-09-21',
#  '2017-09-22',
#  '2017-09-23',
#  '2017-09-24',
#  '2017-09-25',
#  '2017-09-26',
#  '2017-09-27',
#  '2017-09-28',
#  '2017-09-29',
#  '2017-09-30',
#  '2017-10-01',
#  '2017-10-02',
#  '2017-10-03',
#  '2017-10-04',
#  '2017-10-05',
#  '2017-10-06',
#  '2017-10-07',
#  '2017-10-08',
#  '2017-10-09',
#  '2017-10-10',
#  '2017-10-11',
#  '2017-10-12',
#  '2017-10-13',
#  '2017-10-14',
#  '2017-10-15',
#  '2017-10-16',
#  '2017-10-17',
#  '2017-10-18',
#  '2017-10-19',
#  '2017-10-20',
#  '2017-10-21',
#  '2017-10-22',
#  '2017-10-23',
#  '2017-10-24',
#  '2017-10-25',
#  '2017-10-26',
#  '2017-10-27',
#  '2017-10-28',
#  '2017-10-29',
#  '2017-10-30',
#  '2017-10-31',
#  '2017-11-01',
#  '2017-11-02',
#  '2017-11-03',
#  '2017-11-04',
#  '2017-11-05',
#  '2017-11-06',
#  '2017-11-07',
#  '2017-11-08',
#  '2017-11-09',
#  '2017-11-10',
#  '2017-11-11',
#  '2017-11-12',
#  '2017-11-13',
#  '2017-11-14',
#  '2017-11-15',
#  '2017-11-16',
#  '2017-11-17',
#  '2017-11-18',
#  '2017-11-19',
#  '2017-11-20',
#  '2017-11-21',
#  '2017-11-22',
#  '2017-11-23',
#  '2017-11-24',
#  '2017-11-25',
#  '2017-11-26',
#  '2017-11-27',
#  '2017-11-28',
#  '2017-11-29',
#  '2017-11-30',
#  '2017-12-01',
#  '2017-12-02',
#  '2017-12-03',
#  '2017-12-04',
#  '2017-12-05',
#  '2017-12-06',
#  '2017-12-07',
#  '2017-12-08',
#  '2017-12-09',
#  '2017-12-10',
#  '2017-12-11',
#  '2017-12-12',
#  '2017-12-13',
#  '2017-12-14',
#  '2017-12-15',
#  '2017-12-16',
#  '2017-12-17',
#  '2017-12-18',
#  '2017-12-19',
#  '2017-12-20',
#  '2017-12-21',
#  '2017-12-22',
#  '2017-12-23',
#  '2017-12-24',
#  '2017-12-25',
#  '2017-12-26',
#  '2017-12-27',
#  '2017-12-28',
#  '2017-12-29',
#  '2017-12-30',
#  '2017-12-31',
#  '2018-01-01',
#  '2018-01-02',
#  '2018-01-03',
#  '2018-01-04',
#  '2018-01-05',
#  '2018-01-06',
#  '2018-01-07',
#  '2018-01-08',
#  '2018-01-09']

# %%
sns.lineplot(data = spotify)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize =(16,7))
plt.ticklabel_format(style = 'plain')
sns.lineplot(data = spotify['Shape of You'], color ="r")
# Out:
# <AxesSubplot:ylabel='Shape of You'>

# %%
fig, ax = plt.figure(figsize =(16,7))
plt.ticklabel_format(style = 'plain')
fig = sns.lineplot(data = spotify['Shape of You'], color ="r")

ax.set_xticklabels(labels = spotify.Date.tolist(),rotation = 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8176\1737390899.py in <module>
# ----> 1 fig, ax = plt.figure(figsize =(16,7))
#       2 plt.ticklabel_format(style = 'plain')
#       3 fig = sns.lineplot(data = spotify['Shape of You'], color ="r")
#       4
#       5 ax.set_xticklabels(labels = spotify.Date.tolist(),rotation = 50)
#
# TypeError: cannot unpack non-iterable Figure object

# %%
###bar plot

# %%
flight_delay = pd.read_csv("data-for-datavis/flight_delays.csv")

# %%
flight_delay.head()
# Out:
#    Month        AA        AS         B6        DL         EV         F9  \
# 0      1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1      2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2      3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3      4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4      5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#          HA         MQ         NK         OO        UA        US        VX  \
# 0  3.512640  18.164974  11.398054  10.889894  6.352729  3.107457  1.420702
# 1  6.029967  21.301627  16.474466   9.588895  7.260662  7.114455  7.784410
# 2  3.468383  11.018418  10.039118   3.181693  4.892212  3.330787  5.348207
# 3  0.011022   5.131228   8.766224   3.223796  4.376092  2.660290  0.995507
# 4  0.826426   5.466790  22.397347   4.141162  6.827695  0.681605  7.102021
#
#          WN
# 0  3.389466
# 1  3.501363
# 2  3.263341
# 3  2.996399
# 4  5.680777

# %%
fig,ax = plt.figure(figsize = (16,7))
fig = sns.barplot(x = flight_delay['Month'], y = flight_delay['AA'])
plt.title("Avg. Arrival Delay - Spirit")
plt.ylabel("Arrival delay in mins.")
month_lst = ['Jan','Feb','March',]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8176\302372012.py in <module>
# ----> 1 fig,ax = plt.figure(figsize = (16,7))
#       2 fig = sns.barplot(x = flight_delay['Month'], y = flight_delay['AA'])
#       3 plt.title("Avg. Arrival Delay - Spirit")
#       4 plt.ylabel("Arrival delay in mins.")
#
# TypeError: cannot unpack non-iterable Figure object

# %%
###heatmap

# %%
flight_delay = pd.read_csv("data-for-datavis/flight_delays.csv")

# %%
sns.heatmap(data = flight_delay)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
corr = flight_delay.corr()

# %%
corr
# Out:
#           Month        AA        AS        B6        DL        EV        F9  \
# Month  1.000000 -0.737316 -0.203214 -0.224313 -0.385650 -0.503141 -0.740020
# AA    -0.737316  1.000000  0.334980  0.429854  0.805229  0.896523  0.903986
# AS    -0.203214  0.334980  1.000000  0.340359  0.394359  0.356608  0.336791
# B6    -0.224313  0.429854  0.340359  1.000000  0.643313  0.342627  0.510718
# DL    -0.385650  0.805229  0.394359  0.643313  1.000000  0.796951  0.783265
# EV    -0.503141  0.896523  0.356608  0.342627  0.796951  1.000000  0.828515
# F9    -0.740020  0.903986  0.336791  0.510718  0.783265  0.828515  1.000000
# HA    -0.496872  0.220065  0.684979  0.467905  0.262251  0.099369  0.273878
# MQ    -0.872390  0.842701  0.283977  0.529724  0.598765  0.721468  0.912984
# NK    -0.180269  0.573716  0.480863  0.032038  0.625277  0.784026  0.414064
# OO    -0.212444  0.620477  0.350657  0.591115  0.569073  0.692697  0.582509
# UA    -0.357995  0.809874  0.457414  0.233021  0.797339  0.911499  0.671986
# US    -0.154768  0.823713  0.489025  0.788345  0.821757  0.669736  0.878874
# VX     0.104613  0.425237  0.229571  0.579750  0.700605  0.462638  0.308397
# WN    -0.118319  0.615664  0.519228  0.151750  0.691805  0.730115  0.465765
#
#              HA        MQ        NK        OO        UA        US        VX  \
# Month -0.496872 -0.872390 -0.180269 -0.212444 -0.357995 -0.154768  0.104613
# AA     0.220065  0.842701  0.573716  0.620477  0.809874  0.823713  0.425237
# AS     0.684979  0.283977  0.480863  0.350657  0.457414  0.489025  0.229571
# B6     0.467905  0.529724  0.032038  0.591115  0.233021  0.788345  0.579750
# DL     0.262251  0.598765  0.625277  0.569073  0.797339  0.821757  0.700605
# EV     0.099369  0.721468  0.784026  0.692697  0.911499  0.669736  0.462638
# F9     0.273878  0.912984  0.414064  0.582509  0.671986  0.878874  0.308397
# HA     1.000000  0.436015  0.176485  0.056941  0.066821  0.586160 -0.008439
# MQ     0.436015  1.000000  0.281890  0.586963  0.503575  0.660181  0.150111
# NK     0.176485  0.281890  1.000000  0.365273  0.827455  0.293515  0.395419
# OO     0.056941  0.586963  0.365273  1.000000  0.626051  0.590313  0.561515
# UA     0.066821  0.503575  0.827455  0.626051  1.000000  0.477816  0.536968
# US     0.586160  0.660181  0.293515  0.590313  0.477816  1.000000  0.333396
# VX    -0.008439  0.150111  0.395419  0.561515  0.536968  0.333396  1.000000
# WN    -0.007296  0.239744  0.742869  0.548304  0.926800  0.242344  0.630278
#
#              WN
# Month -0.118319
# AA     0.615664
# AS     0.519228
# B6     0.151750
# DL     0.691805
# EV     0.730115
# F9     0.465765
# HA    -0.007296
# MQ     0.239744
# NK     0.742869
# OO     0.548304
# UA     0.926800
# US     0.242344
# VX     0.630278
# WN     1.000000

# %%
plt.figure(figsize=(10,6))
corr = flight_delay.corr()

ax = sns.heatmap(corr, vmin = -1, vmax = 1, center = 0)

# %%
plt.figure(figsize=(10,6))
corr = flight_delay.corr()

ax = sns.heatmap(corr, vmin = -1, vmax = 1, center = 0, annot = True)

# %%
###sactterplot

# %%
insurance = pd.read_csv('data-for-datavis/insurance.csv')

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x = insurance['bmi'], y = insurance['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x = insurance['bmi'], y = insurance['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x = insurance['bmi'], y = insurance['charges'], hue = insurance['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x = 'bmi', y = 'charges', hue = 'smoker', data = insurance)

# %%
sns.swarmplot(x = 'bmi', y = 'charges', data = insurance)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.pairplot(insurance)

# %%
###distribution

# %%
iris = pd.read_csv('data-for-datavis/iris.csv')

# %%
iris.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
sns.kdeplot(data = iris['Sepal Length (cm)'],shade = True)
# Out:
# <AxesSubplot:xlabel='Sepal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x = iris['Sepal Length (cm)'], y = iris['Sepal Width (cm)'],kind ='kde')
