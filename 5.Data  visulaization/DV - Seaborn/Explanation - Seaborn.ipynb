# %% [markdown]
# # What is Seaborn?
#
#     Seaborn is a library for making statistical graphics in Python.
#    It builds on top of matplotlib and integrates closely with pandas data structures.
#     Seaborn helps you explore and understand your data.

# %% [markdown]
# # Distribution Plots
# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
#
# * distplot
# * jointplot
# * pairplot
# * rugplot
# * kdeplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(df['total_bill'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### What does kernel density estimate do?
#
#    The Kernel Density Estimation is a mathematic process of finding an estimate probability density function of a random variable. The estimation attempts to infer characteristics of a population, based on a finite data set.

# %%
sns.distplot(df['total_bill'],kde = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(df['total_bill'],kde = False,bins = 30)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # jointplot
# jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what kind parameter to compare with:
#
#             “scatter”
#             “reg”
#             “resid”
#             “kde”
#             “hex”

# %%
sns.jointplot(x= 'total_bill',y = 'tip',data=df)

# %%
sns.jointplot(x= 'total_bill',y = 'tip',data=df,kind = 'hex')

# %%
sns.jointplot(x= 'total_bill',y = 'tip',data=df,kind = 'reg')

# %% [markdown]
# # pairplot
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
sns.pairplot(df)

# %%
sns.pairplot(df)

# %% [markdown]
# # hue is used for mention the catorigal column

# %%
sns.pairplot(df,hue = 'sex')

# %% [markdown]
# # palette is used for background color

# %%
sns.pairplot(df,hue = 'sex',palette = 'coolwarm')

# %% [markdown]
# # rugplot
# rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution. They are the building block of a KDE plot:

# %%
sns.rugplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # kdeplot
# kdeplots are Kernel Density Estimation plots. These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value. For example:
#
# So with our tips dataset:

# %%
sns.kdeplot(df['total_bill'])
sns.rugplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df['tip'])
sns.rugplot(df['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Categorical Data Plots
# Now let's discuss using seaborn to plot **categorical data!** There are a few main plot types for this:
#
# * factorplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
# Let's go through examples of each!

# %% [markdown]
# # barplot

# %%
sns.barplot(x = 'sex',y = 'total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # estimator defalut take mean value thats why using this function

# %%
sns.barplot(x = 'sex',y = 'total_bill',data=df,estimator = np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # countplot

# %%
sns.countplot(x = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # boxplot and violinplot

# %% [markdown]
# ## boxplot is to find a outlier of dataset

# %%
sns.boxplot(x = 'sex',y = 'total_bill',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
# Can do entire dataframe with orient='h'(horizontal)
sns.boxplot(data=df,orient = 'h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x = 'sex',y = 'total_bill',data = df,hue = 'smoker')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # violinplot

# %%
sns.violinplot(x ='day', y = 'total_bill',data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x ='day', y = 'total_bill',data = df,hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # split is used same graph and both side

# %%
sns.violinplot(x ='day', y = 'total_bill',data = df,hue = 'sex',split =True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # stripplot and swarmplot
#
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.stripplot(x = 'day', y = 'total_bill', data= df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = 'day', y = 'total_bill', data= df,jitter = False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = 'day', y = 'total_bill', data= df,hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x = 'day', y = 'total_bill', data= df,hue = 'sex',split = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # swarmplot

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data=df,hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#split renamed to dodge
sns.swarmplot(x = 'day', y = 'total_bill', data=df,hue = 'sex',dodge = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Combining Categorical Plots

# %%
sns.violinplot(x = 'tip', y = 'day', data = df,palette = 'rainbow')
sns.swarmplot(x = 'tip', y = 'day', data = df,color = 'black',size =3)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# # factorplot renamed = catplot  ..... kind is used for with plot you want

# %%
sns.catplot(x = 'sex', y = 'total_bill',data = df,kind = 'bar')

# %% [markdown]
# # Matrix Plots
# Matrix plots allow you to plot data as color-encoded matrices
#
# Let's begin by exploring seaborn's heatmap

# %%
fl = sns.load_dataset('flights')

# %%
fl.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Heatmap

# %%
# corr - means if total_bill increasing means tip also increase thats called correlation
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#annot-True means they given num to heatmap
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# cmap is using to give the color of graph
sns.heatmap(df.corr(),annot = True,cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
fp = fl.pivot_table(values= 'passengers', index = 'month', columns = 'year')

# %%
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,linecolor = 'white', linewidths = 1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# # Grids
# Grids are general types of plots that allow you to map plot types to rows and columns of a grid, this helps you create similar plots separated by features.
#
#
# **grids is used different different plot using the pairgrid same plot**

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.PairGrid(iris)

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# 2,3,4,7,8,12 row - upperis areas
# 1,6,11,16 row - diagonal areas
# 5,9,10,13,14,15 rows - lower areas


a = sns.PairGrid(iris)
a.map(plt.scatter)

# %% [markdown]
# **grids is used different different plot using the pairgrid same plot**

# %%
a = sns.PairGrid(iris)
a.map_diag(plt.hist)
a.map_upper(plt.scatter)
a.map_lower(sns.kdeplot)

# %% [markdown]
# # pairplot

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue = 'species')

# %% [markdown]
# # FaceGrid
#
# FacetGrid is the general way to create grids of plots based off of a feature:

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
d = sns.FacetGrid(df, col = 'time', row = 'smoker')

# %%
d = sns.FacetGrid(df, col = 'time', row = 'smoker')
d.map(plt.hist,'total_bill')

# %%
d = sns.FacetGrid(df, col = 'time', row = 'smoker')
d.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# # legend is used for diferents the plots

# %%
d = sns.FacetGrid(df, col = 'time', row = 'smoker',hue = 'sex')
d.map(plt.scatter,'total_bill','tip').add_legend()

# %% [markdown]
# # JointGrid

# %%
d = sns.JointGrid(x = 'total_bill',y = 'tip', data = df)

# %%
d = sns.JointGrid(x = 'total_bill',y = 'tip', data = df)
# regplot - regression plot(left)
# distplot - distribution plot(right)
d.plot(sns.regplot,sns.distplot)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Regression Plots
# Seaborn has many built-in capabilities for regression plots, however we won't really discuss regression until the machine learning section of the course, so we will only cover the **lmplot()** function for now.
#
# **lmplot** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
#
# Let's explore how this works:

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## linear regression
#    means to find a correlation and to find center line of the plot
#
# # lmplot()

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex',palette = 'coolwarm')

# %% [markdown]
# # Working with Markers
# lmplot kwargs get passed through to **regplot** which is a more general form of lmplot(). regplot has a scatter_kws parameter that gets passed to plt.scatter. So you want to set the s parameter in that dictionary, which corresponds (a bit confusingly) to the squared markersize. In other words you end up passing a dictionary with the base matplotlib arguments, in this case, s for size of a scatter plot. In general, you probably won't remember this off the top of your head, but instead reference the documentation.

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, hue = 'sex',palette = 'coolwarm',markers=['s','d'],scatter_kws={'s':100})

# %% [markdown]
# # Using a Grid
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments:

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, col = 'time')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, col = 'time',row = 'sex')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, col = 'day')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, col = 'day',hue = 'sex')

# %% [markdown]
# # Aspect and Size
# Seaborn figures can have their **size** and **aspect** ratio adjusted with the size and aspect parameters:

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, col = 'day',hue = 'sex',palette = 'coolwarm',aspect =1,size=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Style and Color
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Styles

# %%
sns.countplot(x = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('white')
sns.countplot(x = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style("whitegrid")
sns.countplot(x = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style("ticks")
sns.countplot(x = 'sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Spine Removal

# %%
sns.set_style("ticks")
sns.countplot(x = 'sex',data = df)
sns.despine()

# %%
sns.set_style("white")
sns.countplot(x = 'sex',data = df)
sns.despine(left = True)

# %% [markdown]
# # Size and Aspect
# You can use matplotlib's **plt.figure(figsize=(width,height)** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# 1num - width
# 2num - height

plt.figure(figsize = (10,10))
sns.set_style("white")
sns.countplot(x = 'sex',data = df)
sns.despine(left = True)

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',size=2,aspect=4,data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Scale and Context
# The set_context() allows you to override default parameters:

# %%
sns.set_context('poster',font_scale = 2)
sns.countplot(x = 'sex',data = df, palette = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_context('paper',font_scale = 2)
sns.countplot(x = 'sex',data = df, palette = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_context('notebook',font_scale = 2)
sns.countplot(x = 'sex',data = df, palette = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>
